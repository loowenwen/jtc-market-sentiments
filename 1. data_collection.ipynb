# %% [markdown]
# # Data Collection

# %%
# %pip install requests beautifulsoup4 fake_useragent pandas openpyxl
# Out:
# Requirement already satisfied: requests in ./env/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in ./env/lib/python3.11/site-packages (4.12.3)
# Requirement already satisfied: fake_useragent in ./env/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: pandas in ./env/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: openpyxl in ./env/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.11/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.11/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.11/site-packages (from requests) (2024.7.4)
# Requirement already satisfied: soupsieve>1.2 in ./env/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.23.2 in ./env/lib/python3.11/site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./env/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in ./env/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Web Scraping URLs

# %% [markdown]
# ## Code Function

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import urllib.parse

def google_search(query, num_results, time_filter = None):
    ua = UserAgent()
    headers = {'User-Agent': ua.random}

    query = urllib.parse.quote_plus(query)

    google_url = f"https://www.google.com/search?q={query}&num={num_results}"

    if time_filter:
        google_url += f"&tbs={time_filter}"

    response = requests.get(google_url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        search_results = []

        for g in soup.find_all('div', class_='g'):
            anchors = g.find_all('a')
            if anchors:
                link = anchors[0]['href']
                search_results.append(link)
                
        return search_results
    else:
        print(f"failed to retrieve search results: status code {response.status_code}")
        return []

# %%
def generate_quarters(start_year, end_year):
    quarters = {}
    if end_year == 2024:
        quarters["2024 Q1"] = "cdr:1,cd_min:1/1/2024,cd_max:3/31/2024"
        quarters["2024 Q2"] = "cdr:1,cd_min:4/1/2024,cd_max:6/30/2024" ## might need to update to include the new quarters, as along as the year doesn't have all 4 quarters
        end_year -= 1
    for year in range(start_year, end_year + 1):
        quarters[f"{year} Q1"] = f"cdr:1,cd_min:1/1/{year},cd_max:3/31/{year}"
        quarters[f"{year} Q2"] = f"cdr:1,cd_min:4/1/{year},cd_max:6/30/{year}"
        quarters[f"{year} Q3"] = f"cdr:1,cd_min:7/1/{year},cd_max:9/30/{year}"
        quarters[f"{year} Q4"] = f"cdr:1,cd_min:10/1/{year},cd_max:12/31/{year}"
    return quarters

def generate_query(source_list):
    dictionary = {}
    for source in source_list:
        if source in dictionary:
            continue
        else:
            dictionary[source] = f"singapore industrial property market {source}" ## can change the google search item here
    return dictionary

# %%
import pandas as pd

query_dictionary = generate_query(["cna", "singapore business review"]) ## essentially the full google search item is going to be called "singapore ... market cna", "singapore ... market singapore business review"

quarter_dictionary = generate_quarters(2020, 2024)

headers = ["URLs", "Source", "Quarter"]
df = pd.DataFrame(columns=headers)

for source, query in query_dictionary.items():
    for quarter, time_filter in quarter_dictionary.items():
        results = google_search(query, num_results=30, time_filter=time_filter)
        temp_df = pd.DataFrame({"URLs": results, "Source": source, "Quarter": quarter})
        df = pd.concat([df, temp_df], ignore_index=True)

print(df)

query_dictionary = generate_query(["straits times", "business times", "edgeprop"])

quarter_dictionary = generate_quarters(2020, 2024)

for source, query in query_dictionary.items():
    for quarter, time_filter in quarter_dictionary.items():
        results = google_search(query, num_results=50, time_filter=time_filter)
        temp_df = pd.DataFrame({"URLs": results, "Source": source, "Quarter": quarter})
        df = pd.concat([df, temp_df], ignore_index=True)

print(df)

df.to_excel("urls.xlsx", index=False) ## saved to excel file called "urls"
# Out:
#                                                   URLs  \
# 0    https://www.channelnewsasia.com/business/singa...
# 1    https://m.facebook.com/SingaporePropertyAdviso...
# 2    https://m.facebook.com/story.php?story_fbid=28...
# 3    https://www.reddit.com/r/singapore/comments/fk...
# 4                    https://www.pbarobotics.com/media
# ..                                                 ...
# 681  https://www.edgeprop.sg/industrial/mandai-indu...
# 682  https://www.propertyguru.com.sg/property-manag...
# 683        https://www.youtube.com/watch?v=Mn07tstnDvA
# 684  https://www.businesstimes.com.sg/property/rent...
# 685  https://www.mof.gov.sg/news-publications/speec...
#
#                         Source  Quarter
# 0                          cna  2020 Q1
# 1                          cna  2020 Q1
# 2                          cna  2020 Q1
# 3                          cna  2020 Q1
# 4                          cna  2020 Q1
# ..                         ...      ...
# 681  singapore business review  2023 Q4
# 682  singapore business review  2023 Q4
# 683  singapore business review  2023 Q4
# 684  singapore business review  2023 Q4
# 685  singapore business review  2023 Q4
#
# [686 rows x 3 columns]
#                                                    URLs    Source  Quarter
# 0     https://www.channelnewsasia.com/business/singa...       cna  2020 Q1
# 1     https://m.facebook.com/SingaporePropertyAdviso...       cna  2020 Q1
# 2     https://m.facebook.com/story.php?story_fbid=28...       cna  2020 Q1
# 3     https://www.reddit.com/r/singapore/comments/fk...       cna  2020 Q1
# 4                     https://www.pbarobotics.com/media       cna  2020 Q1
# ...                                                 ...       ...      ...
# 2278  https://www.edgeprop.sg/property-news/singapor...  edgeprop  2023 Q2
# 2279                       https://commercialrealty.sg/  edgeprop  2023 Q2
# 2280  https://www.tiktok.com/@capgoy/video/722507413...  edgeprop  2023 Q2
# 2281  https://www.edgeprop.sg/property-news/singapor...  edgeprop  2023 Q2
# 2282  https://www.edgeprop.sg/property-news/56-units...  edgeprop  2023 Q2
#
# [2283 rows x 3 columns]

# %% [markdown]
# ## Extract URLs from 2000 to 2024

# %%
import pandas as pd

query_dictionary = generate_query(["cna", "singapore business review"])

quarter_dictionary = generate_quarters(2000, 2004) ## adjust the quarters here, i breakdown the quarters as usually the google request would timeout so doing it in batches helps

headers = ["URLs", "Source", "Quarter"]
df = pd.DataFrame(columns=headers)

for source, query in query_dictionary.items():
    for quarter, time_filter in quarter_dictionary.items():
        results = google_search(query, num_results=30, time_filter=time_filter)
        temp_df = pd.DataFrame({"URLs": results, "Source": source, "Quarter": quarter})
        df = pd.concat([df, temp_df], ignore_index=True)

print(df)

query_dictionary = generate_query(["straits times", "business times", "edgeprop"])

quarter_dictionary = generate_quarters(2000, 2004) ## similar to above 

for source, query in query_dictionary.items():
    for quarter, time_filter in quarter_dictionary.items():
        results = google_search(query, num_results=50, time_filter=time_filter)
        temp_df = pd.DataFrame({"URLs": results, "Source": source, "Quarter": quarter})
        df = pd.concat([df, temp_df], ignore_index=True)

print(df)

file_path = 'urls.xlsx'

with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='new') as writer: ## different from the previous code chunk because this append to the existing file and create new sheets
    df.to_excel(writer, sheet_name='2000 - 2004', index=False)
# Out:
#                                                   URLs  \
# 0    https://www.ide.go.jp/library/English/Publish/...
# 1    https://www.singstat.gov.sg/-/media/files/stan...
# 2    https://www.meti.go.jp/meti_lib/report/2022FY/...
# 3    https://www.wto.org/english/tratop_e/tpr_e/tp1...
# 4    https://www.ura.gov.sg/-/media/Corporate/Resou...
# ..                                                 ...
# 691  https://www.annualreports.co.uk/HostedData/Ann...
# 692  https://www.academia.edu/63315195/Industrial_R...
# 693  http://www.reconnectingamerica.org/assets/Uplo...
# 694  https://www.crawco.com/expertise/contacts/scot...
# 695  https://ec.europa.eu/economy_finance/publicati...
#
#                         Source  Quarter
# 0                          cna  2000 Q1
# 1                          cna  2000 Q1
# 2                          cna  2000 Q1
# 3                          cna  2000 Q1
# 4                          cna  2000 Q1
# ..                         ...      ...
# 691  singapore business review  2004 Q4
# 692  singapore business review  2004 Q4
# 693  singapore business review  2004 Q4
# 694  singapore business review  2004 Q4
# 695  singapore business review  2004 Q4
#
# [696 rows x 3 columns]
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
# failed to retrieve search results: status code 429
#                                                   URLs         Source  Quarter
# 0    https://www.ide.go.jp/library/English/Publish/...            cna  2000 Q1
# 1    https://www.singstat.gov.sg/-/media/files/stan...            cna  2000 Q1
# 2    https://www.meti.go.jp/meti_lib/report/2022FY/...            cna  2000 Q1
# 3    https://www.wto.org/english/tratop_e/tpr_e/tp1...            cna  2000 Q1
# 4    https://www.ura.gov.sg/-/media/Corporate/Resou...            cna  2000 Q1
# ..                                                 ...            ...      ...
# 889  https://www.eiilmuniversity.co.in/downloads/Ad...  straits times  2002 Q2
# 890  https://files.libcom.org/files/TheOtherIsrael.pdf  straits times  2002 Q2
# 891  https://ebin.pub/intercultural-communication-i...  straits times  2002 Q2
# 892  https://www.academia.edu/22434179/UNDP_Mongoli...  straits times  2002 Q2
# 893    https://www.penang-traveltips.com/cheapside.htm  straits times  2002 Q2
#
# [894 rows x 3 columns]

# %% [markdown]
# # URLs Cleaning

# %%
## essentially removes duplicated urls for the specified sheet
file_path = 'urls.xlsx'
sheet_to_clean = '2000 - 2004' ## change the sheet name for each run

df = pd.read_excel(file_path, sheet_name=sheet_to_clean)
duplicates = df["URLs"].duplicated(keep=False)
df = df[~duplicates]

with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer: ## it replaces the previous sheet to update the removal of duplicated urls
    df.to_excel(writer, sheet_name=sheet_to_clean, index=False)

# %%
from urllib.parse import urlparse

file_path = 'urls.xlsx'
sheet_to_clean = '2000 - 2004'

df = pd.read_excel(file_path, sheet_name=sheet_to_clean)

## this was used to only filter for urls with these domains, can modify if needed
acceptable_domains = [
    'www.channelnewsasia.com',
    'sbr.com.sg',
    'www.straitstimes.com',
    'www.businesstimes.com.sg',
    'www.edgeprop.sg'
]

## extracts the domain for each url so that it's easier to compare and filter 
def extract_domain(url):
    try:
        return urlparse(url).netloc
    except:
        return ''

df['Domain'] = df['URLs'].apply(extract_domain)

filtered_df = df[df['Domain'].isin(acceptable_domains)]

filtered_df = filtered_df.drop(columns=['Domain'])

print(filtered_df)

with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer: ## similarly, i replace the cleaned urls into the same file called "urls"
    filtered_df.to_excel(writer, sheet_name=sheet_to_clean, index=False)
# Out:
# Empty DataFrame
# Columns: [URLs, Source, Quarter]
# Index: []

# %% [markdown]
# # Date Scraping URLs

# %% [markdown]
# ## Code Function

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_article_date(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        return f"failed to retrieve the webpage: {e}"
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # locate the date in the meta tag with property 'article:published_time'
    date = soup.find('meta', attrs={'property': 'article:published_time'})
    if date:
        return date['content']
    
    # locate the date in the meta tag with name 'cXenseParse:recs:publishtime'
    date = soup.find('meta', attrs={'name': 'cXenseParse:recs:publishtime'})
    if date:
        return date['content']
    
    # locate the date in the meta tag with name 'article:published_time'
    date = soup.find('meta', attrs={'name': 'article:published_time'})
    if date:
        return date['content']
    
    # locate the date 
    time_element = soup.find('time')
    if time_element and 'datetime' in time_element.attrs:
        return time_element['datetime']
    
    # if not found
    return "date not found"

# %% [markdown]
# ## Extract Dates from 2010 to 2024

# %%
excel_file = 'urls.xlsx'
sheet_name = '2020 - 2024' ## need modify the sheet title for each run
df_existing = pd.read_excel(excel_file, sheet_name=sheet_name)

urls = df_existing['URLs'].tolist()

date_data = []
for url in urls:
    date = get_article_date(url)
    print(date)
    date_data.append({'URLs': url, 'Date': date})

df_date = pd.DataFrame(date_data)

df_updated = pd.merge(df_existing, df_date, on='URLs', how='left')

df_updated = df_updated.drop(columns=['Quarter'])

with pd.ExcelWriter(excel_file, engine="openpyxl", mode="a", if_sheet_exists="replace") as writer: ## file saved to "urls"
    df_updated.to_excel(writer, sheet_name=sheet_name, index=False)
# Out:
# 2020-03-13T15:34:45+08:00
# 2020-02-17T06:14:54+08:00
# 2020-10-09T05:59:40+08:00
# 2020-11-29T06:06:44+08:00
# 2020-11-21T06:00:28+08:00
# 2020-10-08T06:04:10+08:00
# 2020-11-28T06:19:08+08:00
# date not found
# 2021-05-23T06:00:45+08:00
# 2021-05-10T06:10:18+08:00
# 2021-05-04T06:11:35+08:00
# 2021-04-03T06:30:00+08:00
# date not found
# 2021-08-20T19:56:32+08:00
# date not found
# date not found
# 2021-09-28T08:30:00+08:00
# 2021-08-14T06:00:00+08:00
# 2021-08-24T06:30:00+08:00
# 2021-08-26T06:06:12+08:00
# 2021-09-09T15:53:00+08:00
# 2021-11-27T06:00:00+08:00
# 2021-12-06T06:00:34+08:00
# 2021-12-09T06:02:28+08:00
# 2021-12-23T08:44:00+08:00
# 2021-10-28T07:49:54+08:00
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/food-ascent
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/north-link-building
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/woodlands-bizhub
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/megawoodlands
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/harper-point
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/luxasia-building
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/cantonment-central
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/313-somerset
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/holland-road-shopping-centre
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/harvest-woodlands
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/woodlands-horizon
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/industrial/first-east-centre
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/industrial-building-tuas-market-68-mil
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/metro-holdings-and-boustead-projects-announce-joint-acquisition-industrial-property-tai-seng-988-mi
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/savills-real-estate-investment-volume-totals-247-bil-2022-down-1-y-o-y
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/singapore-real-estate-market-remain-bright-spot-savills
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/freehold-industrial-building-new-industrial-road-sale
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/industrial-building-toh-tuck-link-sale-30-mil
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/2022-apac-real-estate-investments-down-27-y-o-y-rate-hikes-cooling-sentiment-jll
# date not found
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/am-alpha%E2%80%99s-timing-driven-value-add-real-estate-play
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/shophouse-market-sentiment-turned-cautious-2h2022-knight-frank
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/demand-still-apparent-office-market-despite-global-setbacks-knight-frank
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/industrial-building-yishun-sale-192-mil
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/list-current-en-bloc-developments-and-their-likelihood-success
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/banking-crisis-how-will-real-estate-capital-markets-be-hit
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/singapore-office-rents-see-subdued-growth-1q2023-jll
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/industrial-rents-climb-15-1q2023-new-supply-erodes-occupancy-88
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/higher-supply-industrial-sites-available-under-2h2023-gls-programme
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/supply-driven-office-market-sustain-singapore%E2%80%99s-10-year-usage
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/freehold-industrial-land-kim-chuan-lane-sale-43-mil
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/slow-start-2023-real-estate-investment-sales-amid-market-uncertainties-knight-frank
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/sevens-atelier-purchase-industrial-building-60-bendemeer-road-415-mil
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/real-estate-sector-shows-significant-bounce-back-investment-sales-1q2023-savills
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/servicing-high-net-worth-deep-market-knowledge-key
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/asia-pacific-real-estate-investments-down-30-y-o-y-1q2023-jll
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/climate-controlled-industrial-facility-60-tuas-ave-11-market-50-mil
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/office-rents-grow-sixth-consecutive-quarter-51-1q2023
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/smartisan-development-buys-two-freehold-industrial-sites-mandai-estate-100-million
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/capitaland-ascendas-reit-divests-local-industrial-building-219-premium-2005-purchase-price
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/fewer-commercial-shophouse-sales-1q2023-shophouse-rental-market-remains-brisk-propnex
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/analysis-are-current-asking-prices-unrealistic
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/three-freehold-jalan-besar-shophouses-market-30-mil
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/singapore-property-buying-sentiment-slides-1q2023-amid-high-interest-rates-and-cooling-measures-nus
# failed to retrieve the webpage: 403 Client Error: Forbidden for url: https://www.edgeprop.sg/property-news/56-units-sold-ct-foodnex-launch-underscores-demand-food-factories

# %% [markdown]
# ## 403 Client Error

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_article_date(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Referer': url,
    }
    
    session = requests.Session()
    session.headers.update(headers)
    
    try:
        response = session.get(url)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        return f"failed to retrieve the webpage: {e}"
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # locate the date in the meta tag with property 'article:published_time'
    date = soup.find('meta', attrs={'property': 'article:published_time'})
    if date:
        return date['content']
    
    # locate the date in the meta tag with name 'cXenseParse:recs:publishtime'
    date = soup.find('meta', attrs={'name': 'cXenseParse:recs:publishtime'})
    if date:
        return date['content']
    
    # locate the date in the meta tag with name 'article:published_time'
    date = soup.find('meta', attrs={'name': 'article:published_time'})
    if date:
        return date['content']
    
    # locate the date 
    time_element = soup.find('time')
    if time_element and 'datetime' in time_element.attrs:
        return time_element['datetime']
    
    # if not found
    return "date not found"

# %%
excel_file = 'urls.xlsx'
sheet_name = '2015 - 2019' ## modify the sheet name for each run
df_existing = pd.read_excel(excel_file, sheet_name=sheet_name)

filtered_df = df_existing[df_existing['Date'].astype(str).str.startswith('failed to retrieve the webpage')]

urls = filtered_df['URLs'].tolist()

date_data = []
for url in urls:
    date = get_article_date(url)
    print(date)
    date_data.append({'URLs': url, 'Date': date})

df_date = pd.DataFrame(date_data)

print(df_date)
# Out:
# 2016-09-23T10:30:00+08:00
# 2016-08-01T13:44:00+08:00
# 2016-09-29T15:35:00+08:00
# 2016-07-04T08:00:00+08:00
# 2016-08-12T16:24:00+08:00
# 2016-08-22T08:00:00+08:00
# 2016-09-09T09:00:00+08:00
# 2016-09-26T10:00:00+08:00
# 2016-08-17T11:09:11+08:00
# 2016-08-15T08:00:00+08:00
# 2016-08-19T11:50:18+08:00
# 2016-07-08T18:27:16+08:00
# 2016-08-25T09:50:31+08:00
# 2016-07-18T14:49:21+08:00
# 2016-09-30T09:00:00+08:00
# 2016-07-15T12:12:19+08:00
# 2016-07-27T15:18:30+08:00
# 2016-07-08T09:16:11+08:00
# 2016-09-16T11:28:25+08:00
# 2016-07-25T16:00:00+08:00
# 2016-11-11T10:03:54+08:00
# 2016-10-21T10:00:00+08:00
# 2016-10-28T16:30:02+08:00
# 2016-10-31T13:14:50+08:00
# 2016-12-10T09:00:00+08:00
# 2016-10-21T10:13:37+08:00
# 2016-11-18T10:00:00+08:00
# 2016-12-07T11:28:05+08:00
# 2016-10-28T10:00:00+08:00
# 2016-10-14T10:00:00+08:00
# 2016-12-19T14:22:26+08:00
# 2016-10-10T13:27:23+08:00
# 2016-10-14T10:30:00+08:00
# 2016-11-08T21:06:47+08:00
# 2016-11-16T17:00:00+08:00
# 2016-12-27T09:00:00+08:00
# 2016-10-06T11:24:30+08:00
# 2016-11-25T17:30:24+08:00
# 2016-10-28T10:15:00+08:00
# 2016-12-16T10:30:00+08:00
# 2016-11-18T14:30:00+08:00
# 2016-12-01T16:30:00+08:00
# 2016-11-03T09:51:43+08:00
# 2016-10-30T22:52:54+08:00
# 2016-10-14T01:32:27+08:00
# 2016-11-25T10:00:00+08:00
# 2016-11-10T14:57:20+08:00
# 2016-11-28T17:30:15+08:00
# 2016-11-28T08:00:00+08:00
# 2016-11-18T10:00:00+08:00
# 2016-12-28T09:00:00+08:00
# 2016-10-08T08:00:00+08:00
# 2016-12-30T09:00:00+08:00
# 2016-10-21T10:30:00+08:00
# 2016-11-18T11:26:41+08:00
# 2016-11-13T08:00:00+08:00
# 2018-12-31T07:00:00+08:00
# 2018-11-02T16:40:00+08:00
# 2018-12-03T15:36:53+08:00
# 2018-11-02T17:20:33+08:00
# failed to retrieve the webpage: 429 Client Error: Too Many Requests for url: https://www.edgeprop.sg/property-news/143-million-pair-freehold-shophouses-jalan-besar
# failed to retrieve the webpage: 429 Client Error: Too Many Requests for url: https://www.edgeprop.sg/property-news/under-hammer-unit-visioncrest-going-225-mil
# failed to retrieve the webpage: 429 Client Error: Too Many Requests for url: https://www.edgeprop.sg/property-news/property-auctions-how-low-do-prices-really-go
# failed to retrieve the webpage: 429 Client Error: Too Many Requests for url: https://www.edgeprop.sg/property-news
# failed to retrieve the webpage: 429 Client Error: Too Many Requests for url: https://www.edgeprop.sg/property-news/nouvel-18-sells-16-units-90-buyers-are-foreigners
# failed to retrieve the webpage: 429 Client Error: Too Many Requests for url: https://www.edgeprop.sg/property-news/iwg-banks-multi-brand-strategy-growth
# failed to retrieve the webpage: 429 Client Error: Too Many Requests for url: https://www.edgeprop.sg/property-news/manhattan-house-collective-sale-300-mil
#                                                   URLs  \
# 0    https://www.edgeprop.sg/property-news/act-doub...
# 1    https://www.edgeprop.sg/property-news/vertical...
# 2    https://www.edgeprop.sg/property-news/amoy-str...
# 3    https://www.edgeprop.sg/property-news/beacon-t...
# 4    https://www.edgeprop.sg/property-news/10-reaso...
# ..                                                 ...
# 121  https://www.edgeprop.sg/property-news/ground-f...
# 122  https://www.edgeprop.sg/property-news/cdl-unve...
# 123  https://www.edgeprop.sg/property-news/nouvel-1...
# 124  https://www.edgeprop.sg/property-news/iwg-bank...
# 125  https://www.edgeprop.sg/property-news/manhatta...
#
#                                                   Date
# 0                            2016-09-23T10:30:00+08:00
# 1                            2016-08-01T13:44:00+08:00
# 2                            2016-09-29T15:35:00+08:00
# 3                            2016-07-04T08:00:00+08:00
# 4                            2016-08-12T16:24:00+08:00
# ..                                                 ...
# 121  failed to retrieve the webpage: 429 Client Err...
# 122  failed to retrieve the webpage: 429 Client Err...
# 123  failed to retrieve the webpage: 429 Client Err...
# 124  failed to retrieve the webpage: 429 Client Err...
# 125  failed to retrieve the webpage: 429 Client Err...
#
# [126 rows x 2 columns]

# %%
## this essentially saves the dates into the "urls" file
date_dict = df_date.set_index('URLs')['Date'].to_dict()

df_existing['Date'] = df_existing.apply(
    lambda row: date_dict.get(row['URLs'], row['Date']), axis=1
)

print(df_existing)

with pd.ExcelWriter(excel_file, engine="openpyxl", mode="a", if_sheet_exists="replace") as writer:
    df_existing.to_excel(writer, sheet_name=sheet_name, index=False)
# Out:
#                                                   URLs    Source  \
# 0    https://www.channelnewsasia.com/singapore/ghos...       cna
# 1    https://www.channelnewsasia.com/singapore/comm...       cna
# 2    https://www.channelnewsasia.com/singapore/pear...       cna
# 3    https://www.channelnewsasia.com/singapore/comm...       cna
# 4    https://www.channelnewsasia.com/commentary/emp...       cna
# ..                                                 ...       ...
# 480  https://www.edgeprop.sg/property-news/ground-f...  edgeprop
# 481  https://www.edgeprop.sg/property-news/cdl-unve...  edgeprop
# 482  https://www.edgeprop.sg/property-news/nouvel-1...  edgeprop
# 483  https://www.edgeprop.sg/property-news/iwg-bank...  edgeprop
# 484  https://www.edgeprop.sg/property-news/manhatta...  edgeprop
#
#                                                   Date
# 0                            2017-04-08T09:30:05+08:00
# 1                            2017-07-27T18:28:39+08:00
# 2                            2017-07-08T20:22:10+08:00
# 3                            2018-01-21T06:30:38+08:00
# 4                            2018-06-12T12:44:22+08:00
# ..                                                 ...
# 480  failed to retrieve the webpage: 429 Client Err...
# 481  failed to retrieve the webpage: 429 Client Err...
# 482  failed to retrieve the webpage: 429 Client Err...
# 483  failed to retrieve the webpage: 429 Client Err...
# 484  failed to retrieve the webpage: 429 Client Err...
#
# [485 rows x 3 columns]

# %% [markdown]
# # Text Scraping

# %% [markdown]
# ## Code Function

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

excel_file = 'urls.xlsx' ## at this point the urls file is cleaned (side note it still includes articles not related to industrial as that was done manually)
df = pd.read_excel(excel_file, sheet_name='2020 - 2024')

# %%
urls = df['URLs'].tolist()

text_data = []

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

for index, url in enumerate(urls):
    print(f"processing URL {index + 1}/{len(urls)}: {url}")
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            html = response.text

            soup = BeautifulSoup(html, 'html.parser')

            paragraphs = soup.find_all('p')
            extracted_text = '\n'.join([p.get_text() for p in paragraphs])

            text_data.append({'URLs': url, 'Text': extracted_text})
            print(extracted_text[:60])
        else:
            print(f"failed to retrieve {url}. status code: {response.status_code}")
            text_data.append({'URLs': url, 'Text': ''})
    except Exception as e:
        print(f"error fetching {url}: {str(e)}")
        text_data.append({'URLs': url, 'Text': ''}) 

text = pd.DataFrame(text_data)
# Out:
# processing URL 1/589: https://www.channelnewsasia.com/business/singapore-shares-sgx-stocks-10-year-low-covid-19-coronavirus-771846
#
#
#       Business
#
#
#
#
#       Business
#
#
# An SGX sign is pic
# processing URL 2/589: https://www.channelnewsasia.com/commentary/singapore-tech-entrepreneurs-start-up-grants-youth-challenge-774631
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 12
#      10 print(f"processing URL {index + 1}/{len(urls)}: {url}")
#      11 try:
# ---> 12     response = requests.get(url, headers=headers)
#      13     if response.status_code == 200:
#      14         html = response.text
#
# File ~/Desktop/Visual Code Studio/jtc-market-sentiments/env/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Desktop/Visual Code Studio/jtc-market-sentiments/env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/Visual Code Studio/jtc-market-sentiments/env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/Visual Code Studio/jtc-market-sentiments/env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/Visual Code Studio/jtc-market-sentiments/env/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Desktop/Visual Code Studio/jtc-market-sentiments/env/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Desktop/Visual Code Studio/jtc-market-sentiments/env/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Desktop/Visual Code Studio/jtc-market-sentiments/env/lib/python3.11/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_updated = pd.merge(df, text, on='URLs', how='left')

def clean_string(s):
    if isinstance(s, str):
        return ''.join(c for c in s if ord(c) in range(32, 127))
    return s

df_updated['Text'] = df_updated['Text'].apply(clean_string)

df_updated = df_updated.drop(columns=['Source'])

df_updated.to_excel("texts.xlsx", index=False)

# %% [markdown]
# ## Extract Texts from 2010 - 2024

# %%
file_path = 'urls.xlsx'
sheet_to_clean = '2015 - 2019' ## change the sheet name accordingly 
df = pd.read_excel(file_path, sheet_name=sheet_to_clean)

urls = df['URLs'].tolist()

text_data = []

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

for index, url in enumerate(urls):
    print(f"processing URL {index + 1}/{len(urls)}: {url}")
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            html = response.text

            soup = BeautifulSoup(html, 'html.parser')

            paragraphs = soup.find_all('p')
            extracted_text = '\n'.join([p.get_text() for p in paragraphs])

            text_data.append({'URLs': url, 'Text': extracted_text})
            print(extracted_text[:60])
        else:
            print(f"failed to retrieve {url}. status code: {response.status_code}")
            text_data.append({'URLs': url, 'Text': ''})
    except Exception as e:
        print(f"error fetching {url}: {str(e)}")
        text_data.append({'URLs': url, 'Text': ''}) 

text = pd.DataFrame(text_data)

df_updated = pd.merge(df, text, on='URLs', how='left')

def clean_string(s):
    if isinstance(s, str):
        return ''.join(c for c in s if ord(c) in range(32, 127))
    return s

df_updated['Text'] = df_updated['Text'].apply(clean_string)

df_updated = df_updated.drop(columns=['Source'])

with pd.ExcelWriter('texts.xlsx', engine='openpyxl', mode='a', if_sheet_exists='replace') as writer: ## there are two chunks as the first one creates the file with one dataframe, while this code append the existing file and add new sheets based on the dataframe
    df_updated.to_excel(writer, sheet_name=sheet_to_clean, index=False)
# Out:
# processing URL 1/485: https://www.channelnewsasia.com/singapore/ghosts-and-mass-graves-einstein-10-stories-we-bet-you-didnt-know-about-siglap-1018481
#
#
#       Singapore
#
#
#
#
#       Singapore
#
#
# On the returning
# processing URL 2/485: https://www.channelnewsasia.com/singapore/commentary-ugly-supply-side-dynamics-can-temper-en-bloc-frenzy-1009256
#
#
#       Singapore
#
#
# commentary
#
#
#
#
# commentary
#
#
#       Sing
# processing URL 3/485: https://www.channelnewsasia.com/singapore/pearl-bank-apartments-makes-4th-attempt-en-bloc-sale-1006721
#
#
#       Singapore
#
#
#
#
#       Singapore
#
#
# Pearl Bank Apart
# processing URL 4/485: https://www.channelnewsasia.com/singapore/commentary-what-happens-when-en-bloc-musical-chairs-stop-840001
#
#
#       Singapore
#
#
# commentary
#
#
#
#
# commentary
#
#
#       Sing
# processing URL 5/485: https://www.channelnewsasia.com/commentary/emphasis-home-ownership-hdb-lease-review-of-public-housing-2071266
#
#
#       Commentary
#
#
# commentary
#
#
#
#
# commentary
#
#
#       Com
# processing URL 6/485: https://www.channelnewsasia.com/commentary/singapore-hdb-public-housing-needs-review-homeownership-2071276
#
#
#       Commentary
#
#
# commentary
#
#
#
#
# commentary
#
#
#       Com
# processing URL 7/485: https://www.channelnewsasia.com/commentary/hdb-housing-schemes-vers-seres-hip-ang-mo-kio-799111
#
#
#       Commentary
#
#
# commentary
#
#
#
#
# commentary
#
#
#       Com
# processing URL 8/485: https://www.channelnewsasia.com/commentary/housing-hdb-ageing-flats-expiring-leases-homeownership-compact-806781
#
#
#       Commentary
#
#
# commentary
#
#
#
#
# commentary
#
#
#       Com
# processing URL 9/485: https://www.channelnewsasia.com/commentary/land-bidding-chinese-developers-singapore-property-rising-cost-1320191
#
#
#       Commentary
#
#
# commentary
#
#
#
#
# commentary
#
#
#       Com
# processing URL 10/485: https://www.channelnewsasia.com/singapore/james-dyson-singapore-penthouse-wallich-residence-870461
#
#
#       Singapore
#
#
#
#
#       Singapore
#
#
# James Dyson's ne
# processing URL 11/485: https://www.channelnewsasia.com/cnainsider/beauty-world-centre-old-timers-shopkeepers-fading-strata-mall-1313826
#
#
#       CNA Insider
#
#
#
#
#       CNA Insider
#
#
# Changing con
# processing URL 12/485: https://sbr.com.sg/financial-services/in-focus/discover-firms-are-most-likely-get-delisted-sgx
# Singapore Business Review website works best with Javascript
# processing URL 13/485: https://sbr.com.sg/economy/commentary/why-i-think-young-singaporeans-struggle-be-entrepreneurs
# Singapore Business Review website works best with Javascript
# processing URL 14/485: https://www.businesstimes.com.sg/singapore/economy-policy/stronger-2014-finish-outlook-subdued
# Login
# Growth in Singapore economy beats even most optimistic
# processing URL 15/485: https://sbr.com.sg/economy/news/chart-day-singapore%25E2%2580%2599s-gdp-capita-surged-30-fold-in-30-years-thanks-lky
# Singapore Business Review website works best with Javascript
# processing URL 16/485: https://sbr.com.sg/information-technology/exclusive/former-strategy-advisor-reveals-aspirations-his-newest-mobile-app-s
# Singapore Business Review website works best with Javascript
# processing URL 17/485: https://sbr.com.sg/commercial-property/news/sphs-seletar-mall-officially-opens-doors-shoppers
# Singapore Business Review website works best with Javascript
# processing URL 18/485: https://www.businesstimes.com.sg/property/shaping-skyline-here-and-overseas
# Login
# The heads of six of Singapore's most established prope
# processing URL 19/485: https://sbr.com.sg/commercial-property/news/suntec-city-mall-makeover-fails-work-wonders-suntec-reit
# Singapore Business Review website works best with Javascript
# processing URL 20/485: https://www.edgeprop.sg/property-news/severed-garden-eden-hall
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 21/485: https://www.businesstimes.com.sg/property/developers-calls-extend-project-deadline-meet-no
# Login
# MOF does not see need to relax 5-year deadline for dev
# processing URL 22/485: https://sbr.com.sg/commercial-property/news/massive-warehouse-supply-glut-threatens-industrial-landlords
# Singapore Business Review website works best with Javascript
# processing URL 23/485: https://sbr.com.sg/commercial-property/exclusive/what-are-implications-successful-sale-asia-square-tower-1
# Singapore Business Review website works best with Javascript
# processing URL 24/485: https://sbr.com.sg/media-marketing/news/singapore-business-review-awards-2017-honours-22-outstanding-firms
# Singapore Business Review website works best with Javascript
# processing URL 25/485: https://sbr.com.sg/markets-investing/exclusive/find-out-what-ohmyhome-ceo-rhonda-wong-thinks-about-effective-branding-s
# Singapore Business Review website works best with Javascript
# processing URL 26/485: https://sbr.com.sg/retail/in-focus/singaporean-customers-amongst-worlds-most-demanding
# Singapore Business Review website works best with Javascript
# processing URL 27/485: https://sbr.com.sg/commercial-property/news/ura-tighten-licence-rules-non-resident-developers
# Singapore Business Review website works best with Javascript
# processing URL 28/485: https://sbr.com.sg/transport-logistics/news/glp-goes-private-and-closes-singapores-largest-ma-deal
# Singapore Business Review website works best with Javascript
# processing URL 29/485: https://sbr.com.sg/professional-serviceslegal/exclusive/singapores-most-promising-legal-luminaries-aged-40-and-under
# Singapore Business Review website works best with Javascript
# processing URL 30/485: https://sbr.com.sg/markets-investing/news/propnex-realty-raises-38m-ipo
# Singapore Business Review website works best with Javascript
# processing URL 31/485: https://sbr.com.sg/commercial-property/news/space-supply-business-parks-could-double-2030
# Singapore Business Review website works best with Javascript
# processing URL 32/485: https://sbr.com.sg/residential-property/news/highest-bid-anchorvale-crescent-ec-site-hit-31889m
# Singapore Business Review website works best with Javascript
# processing URL 33/485: https://sbr.com.sg/commercial-property/in-focus/factories-get-facelift-amidst-singapores-industrial-property-sector-tra
# Singapore Business Review website works best with Javascript
# processing URL 34/485: https://sbr.com.sg/residential-property/in-focus/only-top-5-singapore-earners-can-afford-landed-property-study
# Singapore Business Review website works best with Javascript
# processing URL 35/485: https://sbr.com.sg/economy/news/singapore-worlds-best-place-expats-study
# Singapore Business Review website works best with Javascript
# processing URL 36/485: https://sbr.com.sg/co-written-partner/more-news/well-able-holdings-pte-ltd-takes-home-designed-in-singapore-award-mater
# Singapore Business Review website works best with Javascript
# processing URL 37/485: https://sbr.com.sg/commercial-property/in-focus/data-centre-operators-turn-west-amidst-tai-seng-space-crunch
# Singapore Business Review website works best with Javascript
# processing URL 38/485: https://sbr.com.sg/commercial-property/news/katong-plaza-tries-en-bloc-sale-again-188m
# Singapore Business Review website works best with Javascript
# processing URL 39/485: https://sbr.com.sg/commercial-property/news/mapletree-industrial-trust-raise-175m-private-placement
# Singapore Business Review website works best with Javascript
# processing URL 40/485: https://sbr.com.sg/residential-property/in-focus/singapore-still-second-priciest-housing-market-in-world
# Singapore Business Review website works best with Javascript
# processing URL 41/485: https://sbr.com.sg/commercial-property/in-focus/food-factories-are-eating-singapores-industrial-space
# Singapore Business Review website works best with Javascript
# processing URL 42/485: https://sbr.com.sg/economy/exclusive/foreign-direct-investments-us-singapore-hit-over-244b
# Singapore Business Review website works best with Javascript
# processing URL 43/485: https://www.edgeprop.sg/property-news/changi-ranked-top-logistic-micro-market-singapore-colliers
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 44/485: https://sbr.com.sg/economy/commentary/sweet-trap-entrepreneurship
# Singapore Business Review website works best with Javascript
# processing URL 45/485: https://www.businesstimes.com.sg/incoming/keeping-nimble-stay-course
# Login
# How the Soilbuild Group has managed to be a trailblaze
# processing URL 46/485: https://sbr.com.sg/markets-investing/news/singapore-corporates-lag-in-environmental-sustainability
# Singapore Business Review website works best with Javascript
# processing URL 47/485: https://sbr.com.sg/residential-property/in-focus/luxury-homes-flourish-amidst-renewed-vigour-ultra-rich-foreign-buyers
# Singapore Business Review website works best with Javascript
# processing URL 48/485: https://www.edgeprop.sg/property-news/impact-mrt-property-prices
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 49/485: https://www.straitstimes.com/world/british-daily-the-telegraph-names-3-singapore-buildings-in-its-list-of-2015s-best-and-worst
# SINGAPORE - Singapore's The Interlace condominium was named
# processing URL 50/485: https://www.straitstimes.com/business/companies-markets/sgx-to-put-more-safeguards-in-place-for-trading-in-consolidated-shares
# SINGAPORE - SGX is introducing added safeguards for the trad
# processing URL 51/485: https://www.straitstimes.com/business/companies-markets/capitaland-divests-50-stake-in-capitagreen-to-capitaland-commercial-trust
# SINGAPORE - Capitaland Commercial Trust (CCT) is acquiring t
# processing URL 52/485: https://www.straitstimes.com/business/companies-markets/mas-cad-investigating-broking-firms-for-possible-securities-act-breaches
# SINGAPORE - The Monetary Authority of Singapore (MAS) and th
# processing URL 53/485: https://www.straitstimes.com/singapore/education/students-of-industrial-design-focus-on-users-while-pushing-the-boundaries
# SINGAPORE - A dress made of leather scraps; 3D-printed prote
# processing URL 54/485: https://www.straitstimes.com/authors/ng-keng-gene?page=2
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 55/485: https://www.businesstimes.com.sg/international/daily-debrief-what-happened-today-02
# Login
# Stories you might have missed
# Follow
# Barclays purchase
# processing URL 56/485: https://www.straitstimes.com/business/companies-markets/sgx-release-list-of-companies-suspended-for-over-12-months-as-regulatory
# SINGAPORE - The Singapore Exchange (SGX) has released a new
# processing URL 57/485: https://www.straitstimes.com/business/tussle-at-nobel-design-heading-towards-possible-resolution
# SINGAPORE - The quarrel between Nobel Design's former chairm
# processing URL 58/485: https://www.straitstimes.com/singapore/from-the-straits-times-archives-family-feuds-over-fortunes-and-business-empires
# This article was first published on Dec 2, 2016 and last upd
# processing URL 59/485: https://www.straitstimes.com/authors/joyce-lim?page=1
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 60/485: https://www.straitstimes.com/authors/melissa-heng
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 61/485: https://www.straitstimes.com/authors/seow-bei-yi
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 62/485: https://www.businesstimes.com.sg/companies-markets/capital-markets-currencies/singapore-shares-open-higher-tuesday-10
# Login
# Follow
# SINGAPORE share prices opened higher on Tuesday
# processing URL 63/485: https://www.straitstimes.com/authors/rachael-boon
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 64/485: https://www.edgeprop.sg/property-news/singapore-home-prices-have-bottomed-hong-kongs-are-%E2%80%98crazy%E2%80%99-bnp
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 65/485: https://www.straitstimes.com/business/banking/singapore-thrives-as-a-leader-of-the-worlds-offshore-centres-for-trading-chinas
# SINGAPORE - Singapore continues to thrive in its leading pos
# processing URL 66/485: https://www.straitstimes.com/business/property/rare-strata-office-portfolio-in-tanjong-pagars-gb-building-up-for-sale
# SINGAPORE - A "rare" strata office portfolio in the Tanjong
# processing URL 67/485: https://www.straitstimes.com/business/property/freehold-serangoon-building-on-sale-with-52m-guide-price
# SINGAPORE - A freehold commercial property in Serangoon Road
# processing URL 68/485: https://www.straitstimes.com/business/property/government-launches-sale-of-big-38ha-mixed-use-site-at-pasir-ris-central-part-of
# SINGAPORE - A white or mixed-use site at Pasir Ris Central,
# SINGAPORE'S securities market opened on Thursda
# processing URL 87/485: https://www.straitstimes.com/business/economy/asean-opportunities-for-singapore-in-additive-manufacturing-say-experts
# SINGAPORE - Singapore can collaborate with Asean neighbours
# processing URL 88/485: https://www.straitstimes.com/business/companies-markets/future-of-semiconductor-industry-remains-bright-despite-current-slowdown
# SINGAPORE - The current slowdown in the global semiconductor
# processing URL 89/485: https://www.edgeprop.sg/property-news/avoid-worst-time-sell-your-hdb
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 90/485: https://www.straitstimes.com/business/from-shopping-malls-to-airline-hangars-lend-lease-and-its-singapore-projects
# SINGAPORE - Australian property developer and construction g
# processing URL 91/485: https://www.straitstimes.com/authors/tan-hsueh-yun?page=1
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 92/485: https://www.straitstimes.com/business/companies-markets/smrts-privatisation-9-things-to-know-about-the-deal
# Temasek Holdings' unit Belford Investments is offering $1.68
# processing URL 93/485: https://www.straitstimes.com/business/shophouse-at-28-ann-siang-road-sold-for-s52-million
# SINGAPORE - Property investment firm 8M Real Estate is acqui
# processing URL 94/485: https://www.straitstimes.com/business/keppel-corp-unveils-us368-million-investment-in-shanghai-office-tower-and-retail
# SINGAPORE - Singapore's Keppel Corporation is ramping up its
# processing URL 95/485: https://www.straitstimes.com/business/property/tuan-sing-buys-sime-darby-centre-for-365m
# SINGAPORE - Singapore-listed developer Tuan Sing Holdings ha
# processing URL 96/485: https://www.straitstimes.com/authors/tay-hong-yi?page=2
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 97/485: https://www.straitstimes.com/singapore/8-old-school-singapore-firms-that-re-invented-themselves-to-survive
# SINGAPORE - Prime Minister Lee Hsien Loong, in his May Day R
# processing URL 98/485: https://www.edgeprop.sg/property-news/buying-vietnam%E2%80%99s-sizzling-market
# ‘Very attractive yields’
# Set to reap ‘demographic dividend’
#
# processing URL 99/485: https://www.straitstimes.com/business/tenants-at-hub-synergy-point-told-to-pack-up-and-leave-by-year-end
# SINGAPORE - Tenants at a 44-year-old 28-storey office tower
# processing URL 100/485: https://www.straitstimes.com/singapore/peter-ho-although-small-singapore-can-shape-its-future
# SINGAPORE - Singapore may be small but with new technology,
# processing URL 101/485: https://www.businesstimes.com.sg/international/daily-debrief-what-happened-today-8931
# Login
# Stories you might have missed
# Singapore real estate in
# processing URL 102/485: https://www.straitstimes.com/business/top-interns-in-singapore-rake-in-up-to-10000-a-month-at-major-foreign-banks
# SINGAPORE (THE BUSINESS TIMES)- Alex (not his real name) rak
# processing URL 103/485: https://www.straitstimes.com/business/companies-markets/sanli-debuts-78-higher-on-catalist-when-trading-opens
# SINGAPORE - Sanli Environmental, an environmental engineerin
# processing URL 104/485: https://www.straitstimes.com/singapore/housing/80000-singaporeans-to-be-trained-in-construction-technology-by-2025
# SINGAPORE - Instead of sweat, mud and grime, Singaporeans jo
# processing URL 105/485: https://www.straitstimes.com/singapore/new-62m-market-eating-house-and-active-ageing-hub-to-replace-burnt-jurong-west-centre-by
# SINGAPORE - A new complex that includes shops and an active
# processing URL 106/485: https://www.straitstimes.com/authors/anita-gabriel
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 107/485: https://www.straitstimes.com/business/companies-markets/esr-reit-viva-industrial-trust-said-to-plan-merger
# SINGAPORE (BLOOMBERG) - ESR-Reit, which is backed by Warburg
# processing URL 108/485: https://www.straitstimes.com/business/property/mas-puts-more-scrutiny-on-bank-loans-for-property-development
# SINGAPORE (THE BUSINESS TIMES) - A spate of aggressive land
# processing URL 109/485: https://www.straitstimes.com/business/buying-where-theres-chance-of-a-future-boom
# Business owner Jackson Heng graduated from the school of har
# processing URL 110/485: https://www.straitstimes.com/business/property/owner-offers-1696-sq-m-redevelopment-site-in-geylang-for-at-least-s36m
# SINGAPORE - The owner of a 1,696.3 square metre redevelopmen
# processing URL 111/485: https://www.straitstimes.com/singapore/five-electronics-manufacturers-fined-record-195-million-for-price-fixing
# SINGAPORE - Four electronics firms were fined a record total
# processing URL 112/485: https://www.straitstimes.com/singapore/pearl-bank-apartments-sold-what-makes-the-development-so-iconic
# SINGAPORE - The iconic Pearl Bank Apartments in Outram was s
# processing URL 113/485: https://www.edgeprop.sg/property-news/real-life-dos-and-donts-property-investing-2462166-0
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 114/485: https://www.straitstimes.com/business/property/park-place-residences-at-paya-lebar-quarter-to-launch-final-219-units-for-sale-on
# SINGAPORE - Park Place Residences at Paya Lebar Quarter (PLQ
# processing URL 115/485: https://www.edgeprop.sg/property-news/property-prices-rise-7-2018
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 116/485: https://www.straitstimes.com/singapore/housing/pearl-bank-apartments-likely-to-be-demolished
# SINGAPORE - It was once Singapore's tallest residential buil
# processing URL 117/485: https://www.businesstimes.com.sg/property/peoples-park-complex-peoples-park-centre-golden-mile-complex-and-golden-mile-tower
# Login
# RIDING on the wave of en bloc fever, four post-indepen
# processing URL 118/485: https://www.straitstimes.com/business/companies-markets/capitaland-acquires-pearl-bank-apartments-for-s728m-q4-profit-falls-38
# SINGAPORE - The landmark horse-shoe shaped Pearl Bank Apartm
# processing URL 119/485: https://www.straitstimes.com/authors/claire-huang
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 120/485: https://www.straitstimes.com/authors/lim-min-zhang?page=2
# Min Zhang joined The Straits Times in 2017 after reading phi
# processing URL 121/485: https://www.straitstimes.com/authors/kua-yu-lin
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 122/485: https://www.straitstimes.com/authors/aw-cheng-wei?page=1
# Cheng Wei writes about China’s social and economic trends fo
# processing URL 123/485: https://www.straitstimes.com/lifestyle/yishun-fast-becoming-popular-for-green-spaces-and-amenities
# The cafes are always a sign. Call them the "coolness" litmus
# processing URL 124/485: https://www.straitstimes.com/singapore/health/competition-watchdog-blocks-bid-by-parkway-to-buy-rival-firm
# SINGAPORE - Upmarket Singapore-based property group SC Globa
# processing URL 144/485: https://www.edgeprop.sg/property-news/lawrence-wong-urges-prudence-buyers-and-developers
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 145/485: https://www.straitstimes.com/business/companies-markets/singhaiyi-takes-stake-in-cromwell-property-group
# SINGAPORE - Mainboard-listed real estate group SingHaiyi has
# processing URL 146/485: https://www.straitstimes.com/singapore/orchard-road-blueprint-to-guide-development-over-next-15-to-20-years-ura-and-stb
# SINGAPORE - Orchard Road will no longer be the same in 15 to
# processing URL 147/485: https://www.businesstimes.com.sg/companies-markets/how-apple-helped-hi-ps-ceo-recover-his-worst-error
# Login
# Follow
# [SINGAPORE] In 2015, Yao Hsiao Tung was 75 and
# processing URL 148/485: https://www.straitstimes.com/business/property/chinatown-plaza-sold-en-bloc-for-260m
# SINGAPORE - Chinatown Plaza has been sold for $260 million t
# processing URL 149/485: https://www.straitstimes.com/business/property/goldhill-shopping-centre-in-novena-up-for-en-bloc-sale-with-425m-reserve-price
# SINGAPORE - Goldhill Shopping Centre in Novena has been laun
# processing URL 150/485: https://www.straitstimes.com/authors/alvin-foo
# MCI (P) 066/10/2023. Published by SPH Media Limited, Co. Reg
# processing URL 151/485: https://www.straitstimes.com/business/property/former-hudc-estate-chancery-court-up-for-en-bloc-sale-at-s390m
# SINGAPORE - Chancery Court has launched its collective sale
# processing URL 152/485: https://www.edgeprop.sg/property-news/why-aren%E2%80%99t-rental-yields-rising-along-property-prices
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 153/485: https://www.straitstimes.com/singapore/three-blocks-in-macpherson-lane-get-nod-for-sers
# SINGAPORE - Three Housing Board (HDB) blocks in MacPherson L
# processing URL 154/485: https://www.straitstimes.com/business/property/chancery-court-at-dunearn-road-sells-en-bloc-for-40178m-6-higher-than-reserve
# SINGAPORE - Chancery Court, a privatised HUDC estate across
# processing URL 155/485: https://www.straitstimes.com/business/companies-markets/esr-reit-viva-industrial-trust-to-merge-forming-group-with-3b-in-assets
# SINGAPORE - Managers of ESR-Reit and Viva Industrial Trust (
# processing URL 156/485: https://www.straitstimes.com/business/property/88-market-street-on-former-golden-shoe-car-park-site-secures-jpmorgan-as-anchor
# SINGAPORE - 88 Market Street, the landmark 51-storey tower c
# processing URL 157/485: https://www.businesstimes.com.sg/international/daily-debrief-what-happened-today-16210
# Login
# Stories you might have missed
# Value of IPOs by Singapo
# processing URL 158/485: https://www.straitstimes.com/business/property/bulk-sale-of-22-river-valley-apartments-5-bartley-terrace-houses
# SINGAPORE - Some 22 private apartments in 336 River Valley R
# processing URL 159/485: https://www.straitstimes.com/business/property/newton-lodge-up-for-collective-sale-with-minimum-price-set-at-44m
# SINGAPORE - Owners of Newton Lodge, a 16-unit apartment bloc
# processing URL 160/485: https://www.straitstimes.com/business/property/last-ex-hudc-estate-braddell-view-to-launch-en-bloc-sale-with-208b-reserve-price
# SINGAPORE - Singapore's largest private residential site - B
# processing URL 161/485: https://www.straitstimes.com/business/property/former-house-of-tan-teng-niah-at-little-india-heritage-site-up-for-sale
# SINGAPORE - A conserved two-storey bungalow, known as the fo
# processing URL 162/485: https://www.straitstimes.com/business/property/5-adjoining-kampong-glam-shophouses-on-sale-with-s238m-indicative-price
# SINGAPORE - Five adjoining freehold prime shophouses situate
# processing URL 163/485: https://www.straitstimes.com/business/property/sim-lim-square-up-for-collective-sale-with-125b-reserve-price
# SINGAPORE - Sim Lim Square, Singapore's well-known tech shop
# processing URL 164/485: https://www.straitstimes.com/business/economy/singapore-is-3rd-most-innovative-city-globally-with-innovation-key-to-property
# SINGAPORE - Singapore is the third most innovative city in t
# processing URL 165/485: https://www.straitstimes.com/business/property/realty-centre-in-tanjong-pagar-sells-en-bloc-below-reserve-price-at-148m
# SINGAPORE - Realty Centre, an office building in Tanjong Pag
# processing URL 166/485: https://www.businesstimes.com.sg/property/laurel-tree-sycamore-tree-dispute-buyers-private-matter-ura
# Login
# But Controller of Housing checking for statutory breac
# processing URL 167/485: https://www.straitstimes.com/business/property/bought-for-28m-in-2006-corner-club-street-conservation-shophouse-up-for-sale-at
# SINGAPORE - Bought back in 2006 for $2.8 million, a corner c
# processing URL 168/485: https://www.straitstimes.com/business/property/singapore-shopping-centre-up-for-en-bloc-sale-with-255m-reserve-price
# SINGAPORE - Singapore Shopping Centre has put itself on the
# processing URL 169/485: https://www.straitstimes.com/business/property/ura-launches-tender-of-site-at-jalan-bunga-rampai
# SINGAPORE - A residential site in Jalan Bunga Rampai, off Ba
# processing URL 170/485: https://www.straitstimes.com/business/property/braddell-view-mega-site-relaunched-for-en-bloc-sale-at-same-reserve-price-of-208b
# SINGAPORE - Singapore's largest private residential site - B
# processing URL 171/485: https://www.edgeprop.sg/property-news/first-time-hdb-flat-buyers-get-enhanced-grant-income-ceiling-raised
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 172/485: https://www.straitstimes.com/business/property/good-class-bungalow-in-bukit-panjang-up-for-auction-with-9m-asking-price
# SINGAPORE - A good class bungalow (GCB) at 7 Chestnut Cresce
# processing URL 173/485: https://www.straitstimes.com/business/property/government-keeps-steady-supply-of-private-housing-for-first-half-of-2020-land
# SINGAPORE - The Government has kept largely unchanged the am
# processing URL 174/485: https://www.straitstimes.com/business/property/e-commerce-and-logistics-sector-top-warehouse-occupancy-in-singapore-colliers
# SINGAPORE - The e-commerce and logistics sector accounted fo
# processing URL 175/485: https://www.straitstimes.com/singapore/ara-asset-management-fund-buys-robinson-centre
# SINGAPORE - The Robinson Centre building has been sold to a
# processing URL 176/485: https://www.straitstimes.com/business/companies-markets/unlike-in-singapore-hong-kong-developers-reluctant-to-spin-off-properties
# (BLOOMBERG) - Hong Kong property companies, whose shares hav
# processing URL 177/485: https://www.straitstimes.com/business/property/shophouses-along-bali-lane-duxton-road-up-for-sale-by-tender
# SINGAPORE - A pair of shophouses along Bali Lane in Bugis is
# processing URL 178/485: https://www.edgeprop.sg/property-news/singapore-has-best-prospects-investment-asia-pacific
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 179/485: https://www.straitstimes.com/business/companies-markets/keppel-reit-sells-bugis-junction-towers-for-5475m-388m-above-purchase
# SINGAPORE (THE BUSINESS TIMES) - Keppel Reit has sold Bugis
# processing URL 180/485: https://www.businesstimes.com.sg/companies-markets/singhaiyi-boss-property-leaves-legacy
# Login
# SingHaiyi Group's MD Celine Tang says property is abou
# processing URL 181/485: https://www.edgeprop.sg/property-news/economic-headwinds-may-moderate-industrial-rents-2020
# Newly completed industrial space doubles in 2019
# … as well
# processing URL 182/485: https://www.straitstimes.com/singapore/housing/mixed-use-development-one-holland-village-to-include-homes-retail-offices-and
# SINGAPORE - The upcoming mixed-use development One Holland V
# processing URL 183/485: https://www.businesstimes.com.sg/companies-markets/capital-markets-currencies/keppel-soars-temaseks-wings-lifting-sti-along
# Login
# The promise of restructuring to transform the business
# processing URL 184/485: https://www.straitstimes.com/business/companies-markets/singapore-reit-hopes-to-reopen-damaged-festival-walk-mall-in-hong-kong-in
# SINGAPORE (THE BUSINESS TIMES)- Mapletree North Asia Commerc
# processing URL 185/485: https://www.straitstimes.com/politics/parliament-about-75-of-industrial-emissions-are-from-refining-and-petrochemicals-sector
# SINGAPORE - The Republic's vulnerability to rising sea level
# processing URL 186/485: https://www.businesstimes.com.sg/property/singapore-property-gloom-has-silver-lining-stock-investors
# Login
# Follow
# [SINGAPORE] Here's a good reason to own Singapo
# processing URL 187/485: https://www.businesstimes.com.sg/property/developers-face-hefty-extension-charges-over-unsold-units-amended
# Login
# They may incur up to S$90m from April to December this
# processing URL 188/485: https://www.businesstimes.com.sg/property/jtc-awards-tender-industrial-site-tuas-s561m
# Login
# Follow
# JTC has awarded a tender for a "Business 2" ind
# processing URL 189/485: https://www.businesstimes.com.sg/property/singapore-fund-sold-homes-blackstone-says-market-costly
# Login
# Follow
# [SINGAPORE] SC Capital Partners, which booked a
# processing URL 190/485: https://www.businesstimes.com.sg/companies-markets/soft-market-global-leadership-changes-colliers-see-more-talents-leave-rivals
# Login
# Four members of Colliers' retail team are moving to JL
# processing URL 191/485: https://www.businesstimes.com.sg/opinion-features/columns/pan-el-saga-small-problem-changed-many-things-spore
# Login
# Because of Pan-El, regulation here changed, corporate
# processing URL 192/485: https://www.businesstimes.com.sg/property/binjai-rise-gcb-site-put-auction-lender
# Login
# This will be the first case in at least five years but
# processing URL 193/485: https://www.businesstimes.com.sg/companies-markets/stratech-completes-revamp-eyes-overseas-growth
# Login
# Streamlined group has greater flexibility for acquisit
# processing URL 194/485: https://www.businesstimes.com.sg/incoming/working-her-way-financial-ladder
# Login
# MAIMOONAH Hussain graduated from the National Universi
# processing URL 195/485: https://www.businesstimes.com.sg/property/should-industrial-property-investors-go-leasehold-or-freehold
# Login
# Investors should focus on their objective - immediate
# processing URL 196/485: https://www.businesstimes.com.sg/companies-markets/secura-buy-industrial-property-alexandra-terrace-s165-million
# Login
# SECURA Group has been granted an option by 38@AT to ac
# processing URL 197/485: https://www.businesstimes.com.sg/property/blackstone-buy-three-sime-darby-properties-worth-s300m
# Login
# Follow
# Singapore
# PRIVATE equity giant Blackstone is un
# processing URL 198/485: https://www.businesstimes.com.sg/property/jtc-awards-3-industrial-sites-tampines-and-tuas-south-link-2
# Login
# Follow
# JTC Corporation has awarded its tenders for thr
# processing URL 199/485: https://www.businesstimes.com.sg/property/rental-transactions-jump-march-srx
# Login
# This comes as rents continue their downward trend for
# processing URL 200/485: https://www.businesstimes.com.sg/property/creating-smart-cities
# Login
# Smart technologies can be applied at all levels: from
# processing URL 201/485: https://www.businesstimes.com.sg/property/q1-deals-may-signal-market-good-class-bungalows-looking
# Login
# Follow
# Singapore
# THE Good Class Bungalow (GCB) market
# processing URL 202/485: https://www.businesstimes.com.sg/property/launch-prices-stars-kovan-marked-down
# Login
# The average per square foot price is S$1,417, lower th
# processing URL 203/485: https://www.businesstimes.com.sg/companies-markets/lafe-corp-sgx-watch-list
# Login
# LAFE Corporation, whose operations comprise property i
# processing URL 204/485: https://www.edgeprop.sg/property-news/malls-revitalise-amid-retail-woes
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 205/485: https://www.businesstimes.com.sg/property/some-condos-being-run-serviced-apartments
# Login
# Three, approved for residential use, 'don't have plann
# processing URL 206/485: https://www.businesstimes.com.sg/property/jurong-point-put-market-over-s2b-price-tag
# Login
# Follow
# Singapore
# SINGAPORE'S biggest suburban shopping
# processing URL 207/485: https://www.businesstimes.com.sg/companies-markets/opportunities-in-stocks-of-three-high-end-developers
# Login
# Follow
# AN adage in investment circles goes: be greedy
# processing URL 208/485: https://www.businesstimes.com.sg/property/sabana-reit-buy-paya-lebar-central-property-s345m?amp
# Login
# Follow
# THE managers of Sabana Shari'ah Compliant Indus
# processing URL 209/485: https://www.businesstimes.com.sg/property/two-ultra-high-net-worth-investors-buy-more-property-spore
# Login
# Jewellery business boss buys Nassim Park Residences pe
# processing URL 210/485: https://www.businesstimes.com.sg/real-estate/flash-ura-retail-rental-index-down-15-in-q3-2016-over-q2
# Login
# Follow
# FULL STORY: Vacancy rate for retail space islan
# processing URL 211/485: https://www.businesstimes.com.sg/property/three-residential-developments-orchard-area-sold-s1905m
# Login
# Follow
# THREE prime residential buildings near Orchard
# processing URL 212/485: https://www.businesstimes.com.sg/property/karamjit-singh-leave-jlls-residential-team-pursue-own-interests
# Login
# Follow
# REAL estate consultancy JLL said on Monday en b
# processing URL 213/485: https://sbr.com.sg/commercial-property/news/ccts-growth-hinges-recent-purchase-capitagreen-amidst-tough-times
# Singapore Business Review website works best with Javascript
# processing URL 214/485: https://www.businesstimes.com.sg/property/ascendas-singbridge-jv-redevelop-old-cpf-building
# Login
# Follow
# ASCENDAS-Singbridge Group has entered into a jo
# processing URL 215/485: https://www.businesstimes.com.sg/property/twentyone-angullia-park-owner-talks-bidders
# Login
# CS Land, formerly China Sonangol, is probably selling
# processing URL 216/485: https://www.businesstimes.com.sg/property/chevron-house-sale-over-s700m
# Login
# Follow
# Singapore
# GERMAN open-ended real estate fund De
# processing URL 217/485: https://www.businesstimes.com.sg/property/singapore-developers-seek-top-their-landbank
# Login
# Follow
# Singapore
# THE recent pick-up in residential sit
# processing URL 218/485: https://www.businesstimes.com.sg/property/singapore-penthouse-sale-s100m-test-luxury-markets-recovery
# Login
# Follow
# [SINGAPORE] The asking price for a new three-st
# processing URL 219/485: https://www.businesstimes.com.sg/companies-markets/cct-buy-asia-square-tower-2-s209b
# Login
# CAPITALAND Commercial Trust (CCT) is buying Asia Squar
# processing URL 220/485: https://www.businesstimes.com.sg/ceo-conversations-2017/thriving-disruptive-age
# Hello, your email is unverified. Please confirm  for access
# processing URL 221/485: https://www.businesstimes.com.sg/property/singapore-firms-dip-toes-blockchain-tech-property
# Login
# Two firms are using blockchain platforms to create tok
# processing URL 222/485: https://www.businesstimes.com.sg/inside-invest-aug-2017/building-strong-foundations
# Login
# Mr Chan Kong Leong took over as chief executive office
# processing URL 223/485: https://www.businesstimes.com.sg/property/icb-shopping-centre-headed-en-bloc-launch-s65-70m
# Login
# Analysts expect the mixed-use development to attract s
# processing URL 224/485: https://www.businesstimes.com.sg/companies-markets/s182b-redevelopment-golden-shoe-carpark-unveiled
# Login
# Follow
# Singapore
# IT was, in the words of Lynette Leong
# processing URL 225/485: https://www.businesstimes.com.sg/ceo-conversations-2017/tale-two-developments-mcc-land
# Hello, your email is unverified. Please confirm  for access
# processing URL 226/485: https://www.businesstimes.com.sg/property/govt-trims-industrial-land-supply-after-market-responds-previous-spike
# Login
# Singapore
# THE government is trimming its industrial la
# processing URL 227/485: https://www.businesstimes.com.sg/property/foreign-developers-throwing-lines-singapores-en-bloc-pond
# Login
# Home owners keen on China buyers' deep pockets and app
# processing URL 228/485: https://www.businesstimes.com.sg/property/pearlbank-launch-s728m-how-sun-park-going-s78m
# Login
# It's the fourth collective sale attempt for Pearlbank
# processing URL 229/485: https://www.businesstimes.com.sg/property/spores-hotel-market-draws-investors
# Login
# Potential buyers are scouting for properties amid an a
# processing URL 230/485: https://www.edgeprop.sg/property-news/uol-stays-nimble
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 231/485: https://www.businesstimes.com.sg/property/en-bloc-contagion-spreads-commercial-mixed-use-properties
# Login
# Flood of residential deals re-energises Goldhill Centr
# processing URL 232/485: https://sbr.com.sg/retail/news/chart-day-see-how-upcoming-gst-hike-affects-retail-sales
# Singapore Business Review website works best with Javascript
# processing URL 233/485: https://www.businesstimes.com.sg/wealth/wealth-investing/property-development-lumps-bumps-and-slumps
# Login
# Here's a sector that's relatively easy to understand,
# processing URL 234/485: https://www.businesstimes.com.sg/property/esr-reit-and-vit-merger-could-lead-more-industrial-reit-deals
# Login
# Analysts say if proposed merger does not pan out, it c
# processing URL 235/485: https://www.businesstimes.com.sg/opinion-features/features/prime-heritage-play
# Login
# Shophouse prices have appreciated significantly in the
# processing URL 236/485: https://www.businesstimes.com.sg/property/far-east-bags-coveted-holland-site-s12b
# Login
# Follow
# Singapore
# A CONSORTIUM led by property giant Fa
# processing URL 237/485: https://www.businesstimes.com.sg/property/house-tan-yeok-nee-back-market
# Login
# Singapore
# THE House of Tan Yeok Nee , a gazetted natio
# processing URL 238/485: https://www.businesstimes.com.sg/property/indonesian-group-buys-2-floors-octagon-s303-million
# Login
# At Springleaf Tower, 20th floor changes hands for S$25
# processing URL 239/485: https://www.businesstimes.com.sg/property/spanish-village-put-collective-sale-s882m
# Login
# Marketing agent says asking price for freehold propert
# processing URL 240/485: https://www.businesstimes.com.sg/companies-markets/sph-reit-acquire-rail-mall-s6324m
# Login
# Follow
# Singapore
# SPH Reit has agreed to acquire The Ra
# processing URL 241/485: https://www.businesstimes.com.sg/property/cdls-new-futura-sells-70-phase-2-units-released-friday-average-over-s3500-psf
# Login
# IN a matter of days, City Developments Limited (CDL) h
# processing URL 242/485: https://www.businesstimes.com.sg/property/elias-green-condo-targeting-en-bloc
# Login
# But some observers are wondering if reserve price may
# processing URL 243/485: https://www.businesstimes.com.sg/property/property-2018-september-issue/woodlands-industrys-magnetic-north
# Login
# Plans for the area, its sizeable demographics and mode
# processing URL 244/485: https://www.businesstimes.com.sg/property/property-2018-september-issue/shophouses-investing-singapores-heritage
# Login
# These scarce and highly prized cultural icons have an
# processing URL 245/485: https://www.businesstimes.com.sg/companies-markets/keong-hong-holdings-buy-chin-bee-industrial-buildings-s108-million
# Login
# CONSTRUCTION and property group Keong Hong Holdings pl
# processing URL 246/485: https://www.businesstimes.com.sg/property/freehold-commercial-corner-site-near-farrer-park-mrt-sale
# Login
# Indicative guide price is around S$22m, which works ou
# processing URL 247/485: https://www.businesstimes.com.sg/singapore/smes/leaders-transformation/property-agency-tech-edge
# Login
# OrangeTee & Tie, an early adopter of digital technolog
# processing URL 248/485: https://www.businesstimes.com.sg/property/space-was-luxury-then-small-trend-now-sc-global-changes-tack
# Login
# Singapore
# THE times they are a changin' - even for hig
# processing URL 249/485: https://www.businesstimes.com.sg/property/fresh-property-cooling-measures-spark-last-minute-buying-frenzy
# Login
# ABSD rate raised 5 percentage points for Singaporeans
# processing URL 250/485: https://www.businesstimes.com.sg/property/measured-bid-counts-latest-government-land-sales-tenders-private-housing
# Login
# Follow
# Singapore
# BIDDING turnouts at two of three stat
# processing URL 251/485: https://www.businesstimes.com.sg/opinion-features/features/property-merry-go-round-anomalies-market
# Login
# A look at some unexpected consequences in the property
# processing URL 252/485: https://www.businesstimes.com.sg/property/singapore-property-not-set-big-bump-capitaland-says?xtor=CS3-24
# Login
# Follow
# [SINGAPORE] Singapore home prices are unlikely
# processing URL 253/485: https://www.businesstimes.com.sg/opinion-features/features/life-after-en-bloc1
# Login
# While a collective sale brings windfall gains and fina
# processing URL 254/485: https://www.businesstimes.com.sg/property/price-land-singapore-public-housing-lower-private-developments
# Login
# Follow
# Singapore
# THE average price of land paid for pr
# processing URL 255/485: https://www.businesstimes.com.sg/companies-markets/braddell-views-enbloc-success-may-hinge-creative-use-site
# Login
# Follow
# BELATEDLY or not, a behemoth has lumbered its w
# processing URL 256/485: https://www.edgeprop.sg/property-news/singaporeans-are-loving-luxury-homes-foreigners-cant-buy
# Top of the Class
#
#
# Our Site
# Follow Us
# Edgeprop
# Property Ne
# processing URL 257/485: https://www.businesstimes.com.sg/opinion-features/features/us-reits-singapore
# Login
# A look at their prospects and performance
# Follow
# The S
# processing URL 258/485: https://www.businesstimes.com.sg/companies-markets/banking-finance/singapores-asset-management-industry-grew-slower-54-pace-s34
# Login
# Follow
# DESPITE a challenging year for global financial
# processing URL 259/485: https://www.businesstimes.com.sg/property/geylang-shophouses-sale-s40-42m-joo-chiat-shophouses-put-market-s7-75m
# Login
# Follow
# A ROW of seven adjoining conservation shophouse
# processing URL 260/485: https://www.businesstimes.com.sg/property/71-robinson-road-office-block-sold-s655m-investment-firm-sv-robinson
# Login
# ...
# processing URL 418/485: https://www.edgeprop.sg/property-news/merchants-building-south-bridge-road-collective-sale
# failed to retrieve https://www.edgeprop.sg/property-news/merchants-building-south-bridge-road-collective-sale. status code: 429
# processing URL 419/485: https://www.edgeprop.sg/property-news/why-park-colonial-top-selling-project-3q2018
# failed to retrieve https://www.edgeprop.sg/property-news/why-park-colonial-top-selling-project-3q2018. status code: 429
# processing URL 420/485: https://www.edgeprop.sg/property-news/how-do-mrt-stations-affect-property-prices-and-rent
# failed to retrieve https://www.edgeprop.sg/property-news/how-do-mrt-stations-affect-property-prices-and-rent. status code: 429
# processing URL 421/485: https://www.edgeprop.sg/property-news/tanglin-view-unit-sale-32-mil
# failed to retrieve https://www.edgeprop.sg/property-news/tanglin-view-unit-sale-32-mil. status code: 429
# processing URL 422/485: https://www.edgeprop.sg/property-news/v-shenton-new-icon-heart-singapore%E2%80%99s-financial-district
# failed to retrieve https://www.edgeprop.sg/property-news/v-shenton-new-icon-heart-singapore%E2%80%99s-financial-district. status code: 429
# processing URL 423/485: https://www.edgeprop.sg/property-news/8-st-thomas-holds-its-ground
# failed to retrieve https://www.edgeprop.sg/property-news/8-st-thomas-holds-its-ground. status code: 429
# processing URL 424/485: https://www.edgeprop.sg/property-news/mcl-land-sells-329-units-parc-esta-average-price-1680-psf
# failed to retrieve https://www.edgeprop.sg/property-news/mcl-land-sells-329-units-parc-esta-average-price-1680-psf. status code: 429
# processing URL 425/485: https://www.edgeprop.sg/property-news/surge-top-end-prices-2018
# failed to retrieve https://www.edgeprop.sg/property-news/surge-top-end-prices-2018. status code: 429
# processing URL 426/485: https://www.edgeprop.sg/property-news/mixed-prospects-singapore-property-market
# failed to retrieve https://www.edgeprop.sg/property-news/mixed-prospects-singapore-property-market. status code: 429
# processing URL 427/485: https://www.edgeprop.sg/property-news/freehold-industrial-building-macpherson-sale-159-mil
# Our Site
# Follow Us
# Edgeprop
# Property News
# All News
# In-Depth
#
# processing URL 428/485: https://www.edgeprop.sg/property-news/shophouses-ripe-picking
# failed to retrieve https://www.edgeprop.sg/property-news/shophouses-ripe-picking. status code: 429
# processing URL 429/485: https://www.edgeprop.sg/property-news/century-warehouse-sold-485-million
# failed to retrieve https://www.edgeprop.sg/property-news/century-warehouse-sold-485-million. status code: 429
# processing URL 430/485: https://www.edgeprop.sg/property-news/slb-development-looks-new-horizons
# failed to retrieve https://www.edgeprop.sg/property-news/slb-development-looks-new-horizons. status code: 429
# processing URL 431/485: https://www.edgeprop.sg/property-news/close-31-units-sold-1953
# failed to retrieve https://www.edgeprop.sg/property-news/close-31-units-sold-1953. status code: 429
# processing URL 432/485: https://www.edgeprop.sg/property-news/food-factory-sale-boon-lay-18-million
# failed to retrieve https://www.edgeprop.sg/property-news/food-factory-sale-boon-lay-18-million. status code: 429
# processing URL 433/485: https://www.edgeprop.sg/property-news/orchard-road-retail-rents-may-inch-08-y-o-y-year
# failed to retrieve https://www.edgeprop.sg/property-news/orchard-road-retail-rents-may-inch-08-y-o-y-year. status code: 429
# processing URL 434/485: https://www.edgeprop.sg/property-news/savills-singapore-launches-business-valuation-advisory-team
# failed to retrieve https://www.edgeprop.sg/property-news/savills-singapore-launches-business-valuation-advisory-team. status code: 429
# processing URL 435/485: https://www.edgeprop.sg/property-news/house-tour-jerome-and-sarahs-charming-home-industrial-style-mezzanine
# failed to retrieve https://www.edgeprop.sg/property-news/house-tour-jerome-and-sarahs-charming-home-industrial-style-mezzanine. status code: 429
# processing URL 436/485: https://www.edgeprop.sg/property-news/city-developments-only-singapore-property-group-listed-gender-equality-index-two-years-running
# failed to retrieve https://www.edgeprop.sg/property-news/city-developments-only-singapore-property-group-listed-gender-equality-index-two-years-running. status code: 429
# processing URL 437/485: https://www.edgeprop.sg/property-news/grab%E2%80%99s-new-one-north-hq-house-its-largest-rd-centre
# failed to retrieve https://www.edgeprop.sg/property-news/grab%E2%80%99s-new-one-north-hq-house-its-largest-rd-centre. status code: 429
# processing URL 438/485: https://www.edgeprop.sg/property-news/sultan-plaza-collective-sale-380-mil
# failed to retrieve https://www.edgeprop.sg/property-news/sultan-plaza-collective-sale-380-mil. status code: 429
# processing URL 439/485: https://www.edgeprop.sg/property-news/139-cecil-street-sale-218-mil
# failed to retrieve https://www.edgeprop.sg/property-news/139-cecil-street-sale-218-mil. status code: 429
# processing URL 440/485: https://www.edgeprop.sg/property-news/unit-sea-view-fetches-1900-psf
# failed to retrieve https://www.edgeprop.sg/property-news/unit-sea-view-fetches-1900-psf. status code: 429
# processing URL 441/485: https://www.edgeprop.sg/property-news/habitap-one-app-rule-them-all
# failed to retrieve https://www.edgeprop.sg/property-news/habitap-one-app-rule-them-all. status code: 429
# processing URL 442/485: https://www.edgeprop.sg/property-news/singapore-investors-snap-us5-billion-chinas-commercial-properties-brushing-aside-trade-war-concerns
# failed to retrieve https://www.edgeprop.sg/property-news/singapore-investors-snap-us5-billion-chinas-commercial-properties-brushing-aside-trade-war-concerns. status code: 429
# processing URL 443/485: https://www.edgeprop.sg/property-news/high-specification-industrial-building-paya-lebar-sale
# failed to retrieve https://www.edgeprop.sg/property-news/high-specification-industrial-building-paya-lebar-sale. status code: 429
# processing URL 444/485: https://www.edgeprop.sg/property-news/freehold-industrial-building-aljunied-sale-23-mil
# failed to retrieve https://www.edgeprop.sg/property-news/freehold-industrial-building-aljunied-sale-23-mil. status code: 429
# processing URL 445/485: https://www.edgeprop.sg/property-news/food-factories-offer-higher-yields-compared-office-retail-colliers
# failed to retrieve https://www.edgeprop.sg/property-news/food-factories-offer-higher-yields-compared-office-retail-colliers. status code: 429
# processing URL 446/485: https://www.edgeprop.sg/property-news/freehold-commercial-building-joo-chiat-market-20-mil
# failed to retrieve https://www.edgeprop.sg/property-news/freehold-commercial-building-joo-chiat-market-20-mil. status code: 429
# processing URL 447/485: https://www.edgeprop.sg/property-news/revitalising-potong-pasir%E2%80%99s-private-property-market
# failed to retrieve https://www.edgeprop.sg/property-news/revitalising-potong-pasir%E2%80%99s-private-property-market. status code: 429
# processing URL 448/485: https://www.edgeprop.sg/property-news/singapore-evolves-so-does-edgeprop
# failed to retrieve https://www.edgeprop.sg/property-news/singapore-evolves-so-does-edgeprop. status code: 429
# processing URL 449/485: https://www.edgeprop.sg/property-news/two-freehold-commercial-shophouses-sale
# failed to retrieve https://www.edgeprop.sg/property-news/two-freehold-commercial-shophouses-sale. status code: 429
# processing URL 450/485: https://www.edgeprop.sg/property-news/shophouses-kampong-glam-and-little-india-poised-be-next-growth-area
# failed to retrieve https://www.edgeprop.sg/property-news/shophouses-kampong-glam-and-little-india-poised-be-next-growth-area. status code: 429
# processing URL 451/485: https://www.edgeprop.sg/property-news/property-bukit-merah
# failed to retrieve https://www.edgeprop.sg/property-news/property-bukit-merah. status code: 429
# processing URL 452/485: https://www.edgeprop.sg/property-news/three-office-units-peninsular-plaza-going-929-mil
# failed to retrieve https://www.edgeprop.sg/property-news/three-office-units-peninsular-plaza-going-929-mil. status code: 429
# processing URL 453/485: https://www.edgeprop.sg/property-news/top-gainer-makes-record-169-mil-profit-watermark-robertson-quay
# failed to retrieve https://www.edgeprop.sg/property-news/top-gainer-makes-record-169-mil-profit-watermark-robertson-quay. status code: 429
# processing URL 454/485: https://www.edgeprop.sg/property-news/big-box-building-jurong-east-put-sale-managers
# failed to retrieve https://www.edgeprop.sg/property-news/big-box-building-jurong-east-put-sale-managers. status code: 429
# processing URL 455/485: https://www.edgeprop.sg/property-news/cushman-wakefield%E2%80%99s-dennis-yeo-set-play-%E2%80%98premier-league%E2%80%99
# failed to retrieve https://www.edgeprop.sg/property-news/cushman-wakefield%E2%80%99s-dennis-yeo-set-play-%E2%80%98premier-league%E2%80%99. status code: 429
# processing URL 456/485: https://www.edgeprop.sg/property-news/five-adjoining-freehold-shophouses-kampong-glam-sale
# failed to retrieve https://www.edgeprop.sg/property-news/five-adjoining-freehold-shophouses-kampong-glam-sale. status code: 429
# processing URL 457/485: https://www.edgeprop.sg/property-news/ageing-buildings-cbd-get-lifeline-0
# failed to retrieve https://www.edgeprop.sg/property-news/ageing-buildings-cbd-get-lifeline-0. status code: 429
# processing URL 458/485: https://www.edgeprop.sg/property-news/evia-real-estate-and-metro-jointly-acquire-7-9-tampines-grande-395-mil
# failed to retrieve https://www.edgeprop.sg/property-news/evia-real-estate-and-metro-jointly-acquire-7-9-tampines-grande-395-mil. status code: 429
# processing URL 459/485: https://www.edgeprop.sg/property-news/glimpse-eden-swire-properties%E2%80%99-first-ultra-luxury-condo-singapore
# failed to retrieve https://www.edgeprop.sg/property-news/glimpse-eden-swire-properties%E2%80%99-first-ultra-luxury-condo-singapore. status code: 429
# processing URL 460/485: https://www.edgeprop.sg/property-news/hdb-shophouse-ang-mo-kio-sale-26-mil
# failed to retrieve https://www.edgeprop.sg/property-news/hdb-shophouse-ang-mo-kio-sale-26-mil. status code: 429
# processing URL 461/485: https://www.edgeprop.sg/property-news/industrial-building-tai-seng-sale-23-mil
# failed to retrieve https://www.edgeprop.sg/property-news/industrial-building-tai-seng-sale-23-mil. status code: 429
# processing URL 462/485: https://www.edgeprop.sg/property-news/logistics-building-spacetampines-market-170-mil
# failed to retrieve https://www.edgeprop.sg/property-news/logistics-building-spacetampines-market-170-mil. status code: 429
# processing URL 463/485: https://www.edgeprop.sg/property-news/reinventing-soilbuild-group
# failed to retrieve https://www.edgeprop.sg/property-news/reinventing-soilbuild-group. status code: 429
# processing URL 464/485: https://www.edgeprop.sg/property-news/conservation-shophouses-geylang-and-joo-chiat-sale
# failed to retrieve https://www.edgeprop.sg/property-news/conservation-shophouses-geylang-and-joo-chiat-sale. status code: 429
# processing URL 465/485: https://www.edgeprop.sg/property-news/freehold-properties-balestier-and-east-coast-sale
# failed to retrieve https://www.edgeprop.sg/property-news/freehold-properties-balestier-and-east-coast-sale. status code: 429
# processing URL 466/485: https://www.edgeprop.sg/property-news/average-cbd-grade-office-rents-hit-10-year-high-2q2019
# failed to retrieve https://www.edgeprop.sg/property-news/average-cbd-grade-office-rents-hit-10-year-high-2q2019. status code: 429
# processing URL 467/485: https://www.edgeprop.sg/property-news/commercial-building-north-bridge-road-sale
# failed to retrieve https://www.edgeprop.sg/property-news/commercial-building-north-bridge-road-sale. status code: 429
# processing URL 468/485: https://www.edgeprop.sg/property-news/singapore-shopping-centre-launched-collective-sale-255-mil
# failed to retrieve https://www.edgeprop.sg/property-news/singapore-shopping-centre-launched-collective-sale-255-mil. status code: 429
# processing URL 469/485: https://www.edgeprop.sg/property-news/steady-stream-well-heeled-visitors-meyer-mansion-preview-weekend
# failed to retrieve https://www.edgeprop.sg/property-news/steady-stream-well-heeled-visitors-meyer-mansion-preview-weekend. status code: 429
# processing URL 470/485: https://www.edgeprop.sg/property-news/richard-jany-weathering-ups-and-downs
# failed to retrieve https://www.edgeprop.sg/property-news/richard-jany-weathering-ups-and-downs. status code: 429
# processing URL 471/485: https://www.edgeprop.sg/property-news/oil-tycoon-shifts-focus-real-estate
# Diverse investment portfolio
# Turnaround
# No ‘cookie-cutter ho
# processing URL 472/485: https://www.edgeprop.sg/property-news/wing-tai-chairman-outlook-singapore-residential-market-still-subdued-despite-pick-sales
# failed to retrieve https://www.edgeprop.sg/property-news/wing-tai-chairman-outlook-singapore-residential-market-still-subdued-despite-pick-sales. status code: 429
# processing URL 473/485: https://www.edgeprop.sg/property-news/shophouse-holland-avenue-sale
# failed to retrieve https://www.edgeprop.sg/property-news/shophouse-holland-avenue-sale. status code: 429
# processing URL 474/485: https://www.edgeprop.sg/property-news/pair-shophouses-duxton-road-market-11-mil
# failed to retrieve https://www.edgeprop.sg/property-news/pair-shophouses-duxton-road-market-11-mil. status code: 429
# processing URL 475/485: https://www.edgeprop.sg/property-news/three-storey-conservation-shophouse-chinatown-sale-85-mil
# failed to retrieve https://www.edgeprop.sg/property-news/three-storey-conservation-shophouse-chinatown-sale-85-mil. status code: 429
# processing URL 476/485: https://www.edgeprop.sg/property-news/under-hammer-unit-coastal-view-residences-going-785000
# failed to retrieve https://www.edgeprop.sg/property-news/under-hammer-unit-coastal-view-residences-going-785000. status code: 429
# processing URL 477/485: https://www.edgeprop.sg/property-news/edmund-tie%E2%80%99s-ceo-putting-people-first
# failed to retrieve https://www.edgeprop.sg/property-news/edmund-tie%E2%80%99s-ceo-putting-people-first. status code: 429
# processing URL 478/485: https://www.edgeprop.sg/property-news/four-freehold-geylang-shophouses-market-14-mil
# failed to retrieve https://www.edgeprop.sg/property-news/four-freehold-geylang-shophouses-market-14-mil. status code: 429
# processing URL 479/485: https://www.edgeprop.sg/property-news/cbre%E2%80%99s-martin-samworth-transcending-space
# failed to retrieve https://www.edgeprop.sg/property-news/cbre%E2%80%99s-martin-samworth-transcending-space. status code: 429
# processing URL 480/485: https://www.edgeprop.sg/property-news/resale-unit-regency-park-reaps-165-mil-profit
# failed to retrieve https://www.edgeprop.sg/property-news/resale-unit-regency-park-reaps-165-mil-profit. status code: 429
# processing URL 481/485: https://www.edgeprop.sg/property-news/ground-floor-unit-bukit-timah-shopping-centre-going-58-mil
# failed to retrieve https://www.edgeprop.sg/property-news/ground-floor-unit-bukit-timah-shopping-centre-going-58-mil. status code: 429
# processing URL 482/485: https://www.edgeprop.sg/property-news/cdl-unveils-republic-plaza-after-70-mil-makeover
# failed to retrieve https://www.edgeprop.sg/property-news/cdl-unveils-republic-plaza-after-70-mil-makeover. status code: 429
# processing URL 483/485: https://www.edgeprop.sg/property-news/nouvel-18-sells-16-units-90-buyers-are-foreigners
# failed to retrieve https://www.edgeprop.sg/property-news/nouvel-18-sells-16-units-90-buyers-are-foreigners. status code: 429
# processing URL 484/485: https://www.edgeprop.sg/property-news/iwg-banks-multi-brand-strategy-growth
# failed to retrieve https://www.edgeprop.sg/property-news/iwg-banks-multi-brand-strategy-growth. status code: 429
# processing URL 485/485: https://www.edgeprop.sg/property-news/manhattan-house-collective-sale-300-mil
# failed to retrieve https://www.edgeprop.sg/property-news/manhattan-house-collective-sale-300-mil. status code: 429

# %% [markdown]
# ## Remove White Spaces

# %%
import pandas as pd

excel_file = 'texts.xlsx'
sheet_name = '2020 - 2024' ## adjust the sheet name accordingly
df = pd.read_excel(excel_file, sheet_name=sheet_name)

# remove leading and trailing whitespaces
df['Text'] = df['Text'].str.strip()
print(df)

# replace multiple spaces between words with a single space
df.loc[:, 'Text'] = df['Text'].str.replace(r'\s+', ' ', regex=True)

with pd.ExcelWriter(excel_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer: ## output as texts file
    df.to_excel(writer, sheet_name=sheet_name, index=False)
